# %% [markdown]
# Analysis of TV Show Ratings

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# I modeled a Simple Linear Regression on TV ratings with the number of reviews. The figure suggests that there might be a quadratic relationship between these two as well as there are other contributing factors to predicting the show rating.
